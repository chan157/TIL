# %% [markdown]
# 커피 자판기 만들기
# 금액 투입
# 커피 선택
# 커피 출력
# 잔액 출력
# 동전 : 500 100 50 1000 등
#
#     * 관리자 모드 / 사용자 모드 구현
#
# ex) 관리자 모드
# 1. 커피 재료 (10잔 입력) => 10잔 출력 가능
# 2. 동전을 투입을 해야함 : 1000 : 30 , 500 : 20, 100 : 50
# 3.
#
# ex ) 사용자
# 1. 커피 품절시 품절 표시
# 2. 금액 투입 기능
# 3. 커피 선택
# 4. 잔액 출금 / 추가 선택
# 5.
#
# 실행
# 1. 관리자 2. 사용자 모드 3. 종료
# 입력 1
# 관리자 모드 실행됩니다.
# 1. 커피 재료 확인 2. 동전 확인
#
# 파일 입출력 해서 상태 구현

# %%
class CoffeeMachine():
    def __init__(self):
        self.path = r"C:\Users\Administrator\Desktop\coffeemachine"
        self.file_name = 'MachineState.txt'
        self.statecheck
        try :
            f.open(path + file_name ,'r')
        except FileNotFoundError:
            f.open(path + file_name,'w')
            
                
            
        self.state = 
        pass
    def StateBrief(self):
        print
# Out:
#   File "<ipython-input-2-2efadcec28dc>", line 13
#     self.state =
#                  ^
# SyntaxError: invalid syntax

# %%
import glob

class CoffeeMachine():
    def __init__(self):
        self.path = r"C:\Users\Administrator\Desktop\coffeemachine"
        self.file_name = 'MachineState.txt'
        print("Coffee Machine is starting !")
        self.StateCheck()
        self.current_value = 0
        self.ModeSelection()
        
    def ModeSelection(self):
        print("Press One Option to Use [1/2/3]")
        print("[1] User [2] Administrator [3] Exit")
        while(1):
            try :
                step01 = int(input())
                if step01 == 1 or step01 == 2 or step01== 3:
                    break
                else:
                    print("Press proper button plz!")
            except (ValueError,TypeError) : 
                print("Press proper button plz!")
        if step01 == 1 :
            self.UserMode()
        elif step01 == 2 :
            self.AdministratorMode():
        else : 
            self.ExitMode()
        
    def InsertCoin(self):
         while(1):
            try :
                coin = int(input("1000 or 500 or 100 : "))
                if coin == 1000 or coin == 500 or coin== 100:
                    break
                else:
                    print("Press proper button plz!")
            except (ValueError,TypeError) : 
                print("Press proper button plz!")
        return coin + self.current_value
        
        
        
    def UserMode(self):
        print("-" * 40)
        if self.coffee <= 0 : 
            print("Sold Out Sorry :( ")
            return self.ExitMode()
        else :
            print("Plz Insert Money")
            self.current_value = self.InsertCoin()
            
        print("Do you like some coffee ?")
        print("The price for the coffee is {}" % self.coffeeprice)
        print("Press One Option to Use [1/2/3]")
        print("[1] Yes [2] No [3] LastSession")
        while(1):
            try :
                step02 = int(input())
                if step02 == 1 or step02 == 2 or step02== 3:
                    break
                else:
                    print("Press proper button plz!")
            except (ValueError,TypeError) : 
                print("Press proper button plz!")
        if step02 == 1 :
            if self.current_value < self.coffeeprice:
                print("Sorry! Your value is not enough.")
                print("Plz Insert more coins")
                self.current_value = self.InsertCoin()
                
            
            
            
        elif step02 == 2 :
            self.ExitMode():
        else : 
            self.ModeSelection()
    
    
    
    def AdministratorMode(self):
        pass
    def ExitMode(self):
        self.StateWrite()
        
        
    def StateCheck(self):
        file = glob.glob(self.path + '/*')
        self.coffeeprice = 300
        if file == [] :
            print("New Coffee is started")
            print("Basic setting is applied")
            self.coffee = 10
            self.money_1000 = 5
            self.money_500  = 5
            self.money_100  = 5
            self.StateWrite()
            
        else :
            f = open(file[0],'r')
            self.coffee_file = f.readlines()
            co, a, b, c = map(int,self.coffee_file[1].split())
            self.coffee = co
            self.money_1000 = a
            self.money_500  = b
            self.money_100  = c
            f.close()
            
        print("-" * 40)
        print("Current Coffee Machine State")
        print("coffee     : %3d" % self.coffee)
        print("money_1000 : %3d" % self.money_1000)
        print("money_500  : %3d" % self.money_500)
        print("money_100  : %3d" % self.money_100)
        print("-" * 40)
        
    def StateWrite(self):
        self.record_seq = 'coffee money_1000 money_500 money_100 \n'
        f = open(path + '\\' + file_name,'w')
        for rec in self.record_seq:
            f.write(rec)
        f.write(str(self.coffee) + ' ')
        f.write(str(self.money_1000) + ' ')
        f.write(str(self.money_500) + ' ')
        f.write(str(self.money_100) + ' ')
        f.close()

# %%
test = CoffeeMachine()
# Out:
# Coffee Machine is starting !
# ----------------------------------------
# Current Coffee Machine State
# coffee     :  10
# money_1000 :   8
# money_500  :   2
# money_100  :   1
# ----------------------------------------
# Press One Option to Use [1/2/3]
# [1] User [2] Administrator [3] Exit

# %%
while(1):
    try :
        step01 = int(input())
        if step01 == 1 or step01 == 2 or step01== 3:
            break
        else:
            print("Press proper button plz!")
    except (ValueError,TypeError) : 
        print("Press proper button plz!")
# Out:
# 6
# Press proper button plz!
# 5
# Press proper button plz!
# 7
# Press proper button plz!
# g
# Press proper button plz!
# t
# Press proper button plz!
# r
# Press proper button plz!
# 3
